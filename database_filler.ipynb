# %%
import pymongo
import names
import random
import datetime

client = pymongo.MongoClient(os.getenv("MONGO_CLIENT_STRING"))
db = client.Triin
documents_to_create = int(input("Numbers of documents to create: "))
for i in range(documents_to_create):
      print(f"{i} out of {documents_to_create}")
      name = names.get_full_name()
      ph_no = ""
      for i in range(0, 8):
            ph_no += str(random.randint(0,9))
      latest = db.Orders.count_documents({}) + 1

      db.Orders.insert_one({
            "client_name": name,
            "client_nr": ph_no,
            "internal_id": latest,
            "ordered_items": [],
            "status": {
                  "packed": random.choice([True, False]),
                  "sent": random.choice([True, False]),
                  "shipment_card": random.choice([True, False]),
                  "at_store": random.choice([True, False])
            },
            "updated_at": datetime.datetime.utcnow(),
            "created_at": datetime.datetime.utcnow()
      })
# Out:
# 0 out of 100
# 1 out of 100
# 2 out of 100
# 3 out of 100
# 4 out of 100
# 5 out of 100
# 6 out of 100
# 7 out of 100
# 8 out of 100
# 9 out of 100
# 10 out of 100
# 11 out of 100
# 12 out of 100
# 13 out of 100
# 14 out of 100
# 15 out of 100
# 16 out of 100
# 17 out of 100
# 18 out of 100
# 19 out of 100
# 20 out of 100
# 21 out of 100
# 22 out of 100
# 23 out of 100
# 24 out of 100
# 25 out of 100
# 26 out of 100
# 27 out of 100
# 28 out of 100
# 29 out of 100
# 30 out of 100
# 31 out of 100
# 32 out of 100
# 33 out of 100
# 34 out of 100
# 35 out of 100
# 36 out of 100
# 37 out of 100
# 38 out of 100
# 39 out of 100
# 40 out of 100
# 41 out of 100
# 42 out of 100
# 43 out of 100
# 44 out of 100
# 45 out of 100
# 46 out of 100
# 47 out of 100
# 48 out of 100
# 49 out of 100
# 50 out of 100
# 51 out of 100
# 52 out of 100
# 53 out of 100
# 54 out of 100
# 55 out of 100
# 56 out of 100
# 57 out of 100
# 58 out of 100
# 59 out of 100
# 60 out of 100
# 61 out of 100
# 62 out of 100
# ...

# %%
import pymongo
import names
import random
import os

client = pymongo.MongoClient(os.getenv("MONGO_CLIENT_STRING"))
db = client.Triin
documents_to_create = int(input("Numbers of documents to create: "))
for i in range(documents_to_create):
      print(f"{i} out of {documents_to_create}")
      name = names.get_full_name()
      ph_no = ""
      for i in range(0, 8):
            ph_no += str(random.randint(0,9))
      latest = db.Items.count_documents({}) + 1

      db.Items.insert_one({
            "item_name": random.choice(["T-shirt", "Pants", "Shoes", "Socks", "Hat", "Gloves", "Jacket", "Sweater", "Dress", "Skirt", "Shorts", "Underwear", "Swimsuit", "Coat", "Scarf", "Belt", "Tie", "Sunglasses", "Jewelry", "Watch", "Wallet", "Bag", "Backpack", "Shirt", "Blouse", "Sweatshirt", "Sweatpants", "Bathing suit", "Bikini", "Robe", "Slippers", "Flip flops", "Sandals", "Boots", "Sneakers", "Dress shoes", "Formal shoes", "Loafers", "Oxfords", "Mules", "Clogs", "Wedges", "Flats", "Heels", "Pumps", "Espadrilles", "Sneakers", "Slippers", "Flip flops", "Sandals", "Boots", "Sneakers", "Dress shoes", "Formal shoes", "Loafers", "Oxfords", "Mules", "Clogs", "Wedges", "Flats", "Heels", "Pumps", "Espadrilles", "Sneakers", "Slippers", "Flip flops", "Sandals", "Boots", "Sneakers", "Dress shoes", "Formal shoes", "Loafers", "Oxfords", "Mules", "Clogs", "Wedges", "Flats", "Heels", "Pumps", "Espadrilles", "Sneakers", "Slippers", "Flip flops", "Sandals", "Boots", "Sneakers", "Dress shoes", "Formal shoes", "Loafers", "Oxfords", "Mules", "Clogs", "Wedges", "Flats", "Heels", "Pumps", "Espadrilles", "Sneakers", "Slippers", "Flip flops", "Sandals", "Boots", "Sneakers", "Dress shoes", "Formal shoes", "Loafers", "Oxfords", "Mules", "Clogs", "Wedges", "Flats", "Heels", "Pumps", "Espadrilles", "Sneakers", "Slippers", "Flip flops", "Sandals", "Boots", "Sneakers", "Dress shoes", "Formal shoes",  ]),
            "item_category": random.choice(["Clothes", "Shoes", "Accessories"]),
            "price": str(random.randint(0, 99)) + "." + str(random.randint(10, 99)),
            "amount": random.randint(1, 100),
            "ordered": random.randint(1, 100),
            "item_id": latest,
      })
# Out:
# 0 out of 50
# 1 out of 50
# 2 out of 50
# 3 out of 50
# 4 out of 50
# 5 out of 50
# 6 out of 50
# 7 out of 50
# 8 out of 50
# 9 out of 50
# 10 out of 50
# 11 out of 50
# 12 out of 50
# 13 out of 50
# 14 out of 50
# 15 out of 50
# 16 out of 50
# 17 out of 50
# 18 out of 50
# 19 out of 50
# 20 out of 50
# 21 out of 50
# 22 out of 50
# 23 out of 50
# 24 out of 50
# 25 out of 50
# 26 out of 50
# 27 out of 50
# 28 out of 50
# 29 out of 50
# 30 out of 50
# 31 out of 50
# 32 out of 50
# 33 out of 50
# 34 out of 50
# 35 out of 50
# 36 out of 50
# 37 out of 50
# 38 out of 50
# 39 out of 50
# 40 out of 50
# 41 out of 50
# 42 out of 50
# 43 out of 50
# 44 out of 50
# 45 out of 50
# 46 out of 50
# 47 out of 50
# 48 out of 50
# 49 out of 50
